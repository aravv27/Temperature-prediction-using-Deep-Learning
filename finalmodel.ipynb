# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import glob
import pandas as pd
from keras.callbacks import EarlyStopping
from sklearn.preprocessing import StandardScaler
from keras.optimizers import Adam

training_path = 'D:\\GDG DS\\dataset\\train\\*.csv'
train_files = glob.glob(training_path)
t_data = pd.concat([pd.read_csv(file) for file in train_files], ignore_index=True)

valid_path = 'D:\\GDG DS\\dataset\\valid\\*.csv'
valid_files = glob.glob(valid_path)
v_data = pd.concat([pd.read_csv(vfile) for vfile in valid_files], ignore_index=True)

# %%
t_data.columns = t_data.columns.str.strip()
v_data.columns = v_data.columns.str.strip()

train_data = t_data.drop(['ID', 'nx'], axis=1)
valid_data = v_data.drop(['ID', 'nx'], axis=1)

X_train = train_data.iloc[:, :51].values  
y_train = train_data.iloc[:, 51:].values   
X_valid = valid_data.iloc[:, :51].values    
y_valid = valid_data.iloc[:, 51:].values     

X_train_sensors = X_train[:, 1:] 
X_valid_sensors = X_valid[:, 1:] 

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_sensors)
X_valid_scaled = scaler.transform(X_valid_sensors)

X_train_reshaped = X_train_scaled.reshape(-1, 50, 1)
X_valid_reshaped = X_valid_scaled.reshape(-1, 50, 1)

# %%
model = Sequential()
model.add(LSTM(100, activation='relu', input_shape=(50, 1), return_sequences=False))
# model.add(Dropout(0.2))
# model.add(Dense(128, activation='relu'))
# model.add(Dropout(0.2))
model.add(Dense(2500))

optimizer = Adam(learning_rate=0.0008, clipnorm=1.0)
model.compile(optimizer=optimizer, loss='mse')

early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
model.fit(X_train_reshaped, y_train, epochs=200, batch_size=20, validation_data=(X_valid_reshaped, y_valid), callbacks=[early_stopping])

predictions = model.predict(X_valid_reshaped)

mse = mean_squared_error(y_valid, predictions)
mae = mean_absolute_error(y_valid, predictions)
r2 = r2_score(y_valid, predictions)

print("Validation MSE:", mse)
print("Validation MAE:", mae)
print("Validation R² Score:", r2)
# Out:
# C:\Users\Aravind\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 11362326.0000 - val_loss: 66222.8984
# Epoch 2/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 133680.0781 - val_loss: 251.4088
# Epoch 3/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 358.7164 - val_loss: 228832.1562
# Epoch 4/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 30826.2793 - val_loss: 203.3438
# Epoch 5/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 199.2595 - val_loss: 169.4037
# Epoch 6/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 155.3317 - val_loss: 119.0750
# Epoch 7/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 120.6319 - val_loss: 112.9503
# Epoch 8/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 111.3267 - val_loss: 119.8819
# Epoch 9/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 113.1613 - val_loss: 107.7112
# Epoch 10/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 108.1011 - val_loss: 106.3318
# Epoch 11/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 104.6303 - val_loss: 101.1014
# Epoch 12/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 101.5359 - val_loss: 98.3395
# Epoch 13/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 97.4168 - val_loss: 90.8473
# Epoch 14/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 90.1454 - val_loss: 80.8805
# Epoch 15/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 83.4294 - val_loss: 75.0035
# Epoch 16/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 76.9049 - val_loss: 79.5766
# Epoch 17/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 77.3443 - val_loss: 69.6562
# Epoch 18/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 71.2927 - val_loss: 74.8336
# Epoch 19/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 70.2882 - val_loss: 68.4527
# Epoch 20/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 67.6214 - val_loss: 64.1877
# Epoch 21/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 64.8295 - val_loss: 63.5010
# Epoch 22/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 62.6292 - val_loss: 66.6983
# Epoch 23/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 58.0547 - val_loss: 56.5690
# Epoch 24/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 56.1364 - val_loss: 59.8538
# Epoch 25/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 52.5818 - val_loss: 50.2150
# Epoch 26/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 48.0501 - val_loss: 49.4647
# Epoch 27/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 45.1374 - val_loss: 44.4545
# Epoch 28/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 43.2027 - val_loss: 41.4616
# Epoch 29/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 41.9999 - val_loss: 40.1273
# Epoch 30/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 39.2391 - val_loss: 36.4031
# Epoch 31/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 35.8519 - val_loss: 36.5374
# Epoch 32/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 35.6619 - val_loss: 36.9404
# Epoch 33/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 33.4030 - val_loss: 36.5982
# Epoch 34/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 32.4302 - val_loss: 36.8797
# Epoch 35/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 30.6558 - val_loss: 32.1064
# Epoch 36/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 30.1924 - val_loss: 27.2265
# Epoch 37/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 27.7281 - val_loss: 27.1788
# Epoch 38/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 27.6579 - val_loss: 24.8538
# Epoch 39/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 25.3003 - val_loss: 23.9134
# Epoch 40/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 24.7259 - val_loss: 23.9225
# Epoch 41/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 25.0028 - val_loss: 22.3011
# Epoch 42/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 22.5806 - val_loss: 22.8866
# Epoch 43/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 22.6277 - val_loss: 23.4086
# Epoch 44/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 22.5496 - val_loss: 20.5820
# Epoch 45/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 21.3227 - val_loss: 19.8766
# Epoch 46/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 20.7639 - val_loss: 20.1928
# Epoch 47/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 20.4435 - val_loss: 19.3039
# Epoch 48/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 19.8640 - val_loss: 19.9063
# Epoch 49/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 19.8017 - val_loss: 17.9414
# Epoch 50/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 19.3372 - val_loss: 18.4441
# Epoch 51/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 18.6305 - val_loss: 17.2925
# Epoch 52/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 17.9731 - val_loss: 17.1538
# Epoch 53/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 17.9928 - val_loss: 17.3596
# Epoch 54/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 17.8077 - val_loss: 18.7302
# Epoch 55/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 17.3516 - val_loss: 16.7414
# Epoch 56/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 17.1632 - val_loss: 16.6303
# Epoch 57/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 16.7196 - val_loss: 17.9863
# Epoch 58/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 16.4198 - val_loss: 17.4451
# Epoch 59/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 16.3788 - val_loss: 15.4316
# Epoch 60/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 15.7545 - val_loss: 15.6700
# Epoch 61/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 15.7590 - val_loss: 17.7540
# Epoch 62/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 15.9100 - val_loss: 15.4664
# Epoch 63/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 15.7157 - val_loss: 15.3883
# Epoch 64/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 14.9671 - val_loss: 15.1689
# Epoch 65/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 15.5449 - val_loss: 15.0333
# Epoch 66/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 14.9039 - val_loss: 16.4408
# Epoch 67/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 14.6768 - val_loss: 12.6871
# Epoch 68/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 14.0158 - val_loss: 13.9939
# Epoch 69/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 14.0266 - val_loss: 12.8495
# Epoch 70/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 13.9960 - val_loss: 17.0571
# Epoch 71/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 13.5692 - val_loss: 14.0614
# Epoch 72/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 13.7009 - val_loss: 12.8203
# Epoch 73/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 13.6694 - val_loss: 12.4689
# Epoch 74/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 13.0905 - val_loss: 11.9122
# Epoch 75/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 12.7442 - val_loss: 12.3318
# Epoch 76/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 12.6954 - val_loss: 12.8559
# Epoch 77/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 12.4537 - val_loss: 12.1059
# Epoch 78/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 12.9283 - val_loss: 12.5842
# Epoch 79/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 12.2143 - val_loss: 13.0355
# Epoch 80/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 12.8783 - val_loss: 11.9589
# Epoch 81/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 12.4833 - val_loss: 12.9631
# Epoch 82/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 12.4745 - val_loss: 11.1881
# Epoch 83/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 11.9052 - val_loss: 15.6898
# Epoch 84/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 12.8570 - val_loss: 11.8344
# Epoch 85/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 12.1388 - val_loss: 10.9340
# Epoch 86/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 11.7646 - val_loss: 12.5920
# Epoch 87/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 11.7568 - val_loss: 11.5909
# Epoch 88/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 11.8290 - val_loss: 11.9185
# Epoch 89/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 11.8990 - val_loss: 10.4703
# Epoch 90/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 11.8174 - val_loss: 11.1459
# Epoch 91/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 11.2111 - val_loss: 14.1400
# Epoch 92/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 11.6283 - val_loss: 11.7682
# Epoch 93/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 11.5878 - val_loss: 11.2378
# Epoch 94/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 11.3240 - val_loss: 12.8938
# Epoch 95/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 11.4310 - val_loss: 11.1075
# Epoch 96/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 10.9728 - val_loss: 10.2561
# Epoch 97/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 10.9117 - val_loss: 11.4114
# Epoch 98/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 11.4617 - val_loss: 11.0743
# Epoch 99/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 10.8879 - val_loss: 10.6188
# Epoch 100/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 11.0333 - val_loss: 12.6788
# Epoch 101/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 11.1013 - val_loss: 9.8935
# Epoch 102/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 10.6456 - val_loss: 10.5383
# Epoch 103/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 10.9447 - val_loss: 9.8534
# Epoch 104/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 10.7699 - val_loss: 10.0806
# Epoch 105/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 10.6053 - val_loss: 10.5567
# Epoch 106/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 11.1975 - val_loss: 9.7641
# Epoch 107/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 10.6099 - val_loss: 9.8257
# Epoch 108/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 10.6332 - val_loss: 10.9702
# Epoch 109/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 10.5487 - val_loss: 9.6345
# Epoch 110/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 10.4890 - val_loss: 10.1845
# Epoch 111/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 10.5712 - val_loss: 10.0000
# Epoch 112/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 10.5323 - val_loss: 9.6131
# Epoch 113/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 10.4565 - val_loss: 10.2924
# Epoch 114/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 10.4000 - val_loss: 10.4031
# Epoch 115/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 10.6729 - val_loss: 9.8342
# Epoch 116/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 10.3494 - val_loss: 9.7989
# Epoch 117/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 10.3404 - val_loss: 9.6547
# Epoch 118/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 10.1918 - val_loss: 9.8300
# Epoch 119/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 10.2822 - val_loss: 9.3377
# Epoch 120/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 10.4098 - val_loss: 10.0560
# Epoch 121/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 10.3096 - val_loss: 10.2676
# Epoch 122/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 10.2810 - val_loss: 9.5966
# Epoch 123/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 10.1402 - val_loss: 9.8902
# Epoch 124/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 10.2810 - val_loss: 9.9367
# Epoch 125/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 10.2262 - val_loss: 9.4084
# Epoch 126/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 9.9480 - val_loss: 10.3663
# Epoch 127/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 10.2366 - val_loss: 11.7115
# Epoch 128/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 10.2697 - val_loss: 10.1684
# Epoch 129/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 10.0689 - val_loss: 9.7957
# Epoch 130/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 10.0349 - val_loss: 9.2564
# Epoch 131/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 10.0061 - val_loss: 9.4621
# Epoch 132/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 9.8964 - val_loss: 9.1914
# Epoch 133/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 10.1083 - val_loss: 9.0141
# Epoch 134/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 9.9321 - val_loss: 9.3413
# Epoch 135/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 10.1131 - val_loss: 9.8853
# Epoch 136/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 9.8839 - val_loss: 10.7942
# Epoch 137/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 10.1528 - val_loss: 9.3440
# Epoch 138/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 9.9679 - val_loss: 9.2357
# Epoch 139/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 9.8673 - val_loss: 9.3539
# Epoch 140/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 9.9372 - val_loss: 9.8805
# Epoch 141/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 9.6724 - val_loss: 9.4550
# Epoch 142/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 9.9304 - val_loss: 9.5267
# Epoch 143/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 10.0257 - val_loss: 9.5348
# Epoch 144/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 9.7880 - val_loss: 8.9593
# Epoch 145/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 9.7418 - val_loss: 8.8335
# Epoch 146/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 9.5986 - val_loss: 9.3362
# Epoch 147/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 9.6017 - val_loss: 9.8451
# Epoch 148/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 9.9169 - val_loss: 9.1825
# Epoch 149/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 9.6930 - val_loss: 9.5524
# Epoch 150/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 9.8524 - val_loss: 9.3400
# Epoch 151/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 9.7677 - val_loss: 10.1205
# Epoch 152/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 9.7032 - val_loss: 9.4320
# Epoch 153/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 9.7137 - val_loss: 9.7450
# Epoch 154/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 9.6746 - val_loss: 9.1657
# Epoch 155/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 9.6508 - val_loss: 9.0350
# Epoch 156/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 9.5754 - val_loss: 9.2820
# Epoch 157/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 9.5780 - val_loss: 9.4016
# Epoch 158/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 9.5729 - val_loss: 9.3404
# Epoch 159/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 9.4179 - val_loss: 9.1167
# Epoch 160/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 9.7055 - val_loss: 9.1327
# Epoch 161/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 9.5268 - val_loss: 8.7747
# Epoch 162/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 9.3984 - val_loss: 9.0075
# Epoch 163/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 9.5033 - val_loss: 8.8674
# Epoch 164/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 9.6672 - val_loss: 8.8288
# Epoch 165/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 9.4191 - val_loss: 8.9722
# Epoch 166/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 9.5037 - val_loss: 9.4095
# Epoch 167/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 9.3067 - val_loss: 9.9251
# Epoch 168/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 9.8292 - val_loss: 8.6454
# Epoch 169/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 9.4000 - val_loss: 8.8669
# Epoch 170/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 9.4296 - val_loss: 10.4528
# Epoch 171/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 9.7694 - val_loss: 8.9908
# Epoch 172/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 9.5284 - val_loss: 8.8584
# Epoch 173/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 9.6537 - val_loss: 8.7903
# Epoch 174/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 9.2920 - val_loss: 9.1043
# Epoch 175/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 9.5097 - val_loss: 8.7998
# Epoch 176/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 9.3633 - val_loss: 9.5348
# Epoch 177/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 9.2883 - val_loss: 9.7742
# Epoch 178/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 9.5097 - val_loss: 9.1734
# Epoch 179/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 9.5362 - val_loss: 8.8895
# Epoch 180/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 9.2955 - val_loss: 8.6560
# Epoch 181/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 9.2703 - val_loss: 9.5717
# Epoch 182/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 9.3625 - val_loss: 8.9999
# Epoch 183/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 9.3042 - val_loss: 9.6429
# Epoch 184/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 9.3641 - val_loss: 8.8371
# Epoch 185/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 9.2891 - val_loss: 8.7742
# Epoch 186/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 9.1395 - val_loss: 9.0358
# Epoch 187/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 9.2930 - val_loss: 9.0786
# Epoch 188/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 9.2612 - val_loss: 8.6494
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# Validation MSE: 8.645371249440291
# Validation MAE: 2.1306149954606073
# Validation R² Score: 0.9476609344036345

# %%
test_data = pd.read_csv("D:\\GDG DS\\dataset\\test\\dataset_0.csv")
test_data.columns = test_data.columns.str.strip()

X_test_features = test_data.iloc[:, 3:53].values
X_test_scaled = scaler.transform(X_test_features)

X_test_reshaped = X_test_scaled.reshape(-1, 50, 1)
test_predictions = model.predict(X_test_reshaped)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step

# %%
predictions_df = pd.DataFrame(test_predictions, columns=[f'val_{i}' for i in range(50, 2550)])


columns_to_keep = ['ID', 'L', 'nx'] + [f'val_{i}' for i in range(50)]
final_test_data = pd.concat([test_data[columns_to_keep], predictions_df], axis=1)

# %%
final_test_data.to_csv("D:\\GDG DS\\dataset\\submission\\submission7.csv", index=False)

print(final_test_data.head())
print(final_test_data.shape)
# Out:
#    ID     L  nx  val_0  val_1   val_2   val_3  val_4   val_5  val_6  ...  \
# 0   0  0.42  50  29.74  52.66   73.03   88.64  97.89  100.00  95.08  ...
# 1   1  1.11  50  31.43  85.09  100.00   70.25  25.09    0.00   5.55  ...
# 2   2  0.67  50  32.52  66.48   91.06  100.00  92.17   71.73  46.49  ...
# 3   3  0.87  50  27.84  72.27   99.23  100.00  78.38   47.69  22.80  ...
# 4   4  0.84  50  34.57  71.48   95.72  100.00  85.19   59.27  33.18  ...
#
#     val_2540   val_2541   val_2542   val_2543   val_2544   val_2545  \
# 0  29.513666  29.800240  29.119366  30.215857  31.552290  34.119270
# 1  32.207390  33.556477  36.431229  37.096989  34.247814  30.950804
# 2  29.722403  29.608234  28.639227  27.668055  24.560699  21.292730
# 3  27.637581  26.657835  24.499636  23.413424  22.740475  24.812342
# 4  30.932081  27.876802  24.161255  24.119654  24.729183  29.783863
#
#     val_2546   val_2547   val_2548   val_2549
# 0  37.077007  42.583729  47.242226  52.060482
# 1  28.744024  29.924498  36.875217  37.325417
# 2  19.541348  17.106768  15.632071  15.081905
# 3  30.562210  36.942390  43.558395  51.579823
# 4  39.376328  48.676090  58.137100  70.131126
#
# [5 rows x 2553 columns]
# (100, 2553)
